# %%
import numpy as np
import joblib
import pandas as pd

# %%
folder_81att=pd.read_csv("scores_lineal_81att_Hiperparametros.csv")
folder_81att
# Out:
#      Unnamed: 0 MODEL    C  Epsilon   Kernel   R2_fold1  R2_fold2  R2_fold3  \
# 0             0   SVR    0      0.0   lineal   0.000000  0.000000  0.000000
# 1             1   SVR    5      0.1   linear  -0.052847 -0.046789 -0.068477
# 2             2   SVR    5      0.2   linear  -0.048964 -0.035798 -0.068165
# 3             3   SVR    5      0.3   linear  -0.043525 -0.035041 -0.067987
# 4             4   SVR    5      0.4   linear  -0.036488 -0.027981 -0.064265
# ..          ...   ...  ...      ...      ...        ...       ...       ...
# 396         396   SVR  100      0.1  sigmoid -11.328302 -7.103623 -7.991758
# 397         397   SVR  100      0.2  sigmoid -11.328302 -7.103623 -7.991758
# 398         398   SVR  100      0.3  sigmoid -11.328302 -7.103623 -7.991758
# 399         399   SVR  100      0.4  sigmoid -11.328302 -7.103623 -7.991758
# 400         400   SVR  100      0.5  sigmoid -11.328302 -7.103623 -7.991758
#
#       R2_fold4   R2_fold5
# 0     0.000000   0.000000
# ...

# %%
folder_81att.loc[ (folder_81att.R2_fold1 > 0) & (folder_81att.R2_fold2 > 0) & (folder_81att.R2_fold3 > 0) & (folder_81att.R2_fold4 > 0) ]
# Out:
#      Unnamed: 0 MODEL   C  Epsilon   Kernel  R2_fold1  R2_fold2  R2_fold3  \
# 6             6   SVR  10      0.1   linear  0.087459  0.094590  0.057237
# 7             7   SVR  10      0.2   linear  0.087826  0.095071  0.057618
# 8             8   SVR  10      0.3   linear  0.088229  0.096473  0.058305
# 9             9   SVR  10      0.4   linear  0.089385  0.098629  0.058732
# 10           10   SVR  10      0.5   linear  0.091891  0.104313  0.060122
# 301         301   SVR   5      0.1  sigmoid  0.038945  0.039847  0.042241
# 302         302   SVR   5      0.2  sigmoid  0.038945  0.039847  0.042241
# 303         303   SVR   5      0.3  sigmoid  0.038945  0.039847  0.042241
# 304         304   SVR   5      0.4  sigmoid  0.038945  0.039847  0.042241
# 305         305   SVR   5      0.5  sigmoid  0.038945  0.039847  0.042241
# 306         306   SVR  10      0.1  sigmoid  0.068452  0.071834  0.076908
# 307         307   SVR  10      0.2  sigmoid  0.068452  0.071834  0.076908
# ...

# %%
folder_81att.loc[ (folder_81att.R2_fold5 > 0.07) ]
# Out:
#      Unnamed: 0 MODEL   C  Epsilon   Kernel  R2_fold1  R2_fold2  R2_fold3  \
# 306         306   SVR  10      0.1  sigmoid  0.068452  0.071834  0.076908
# 307         307   SVR  10      0.2  sigmoid  0.068452  0.071834  0.076908
# 308         308   SVR  10      0.3  sigmoid  0.068452  0.071834  0.076908
# 309         309   SVR  10      0.4  sigmoid  0.068452  0.071834  0.076908
# 310         310   SVR  10      0.5  sigmoid  0.068452  0.071834  0.076908
#
#      R2_fold4  R2_fold5
# 306  0.066798  0.072442
# 307  0.066798  0.072442
# 308  0.066798  0.072442
# 309  0.066798  0.072442
# 310  0.066798  0.072442

# %%
"""
PARAMETROS:
SVR 10 0.5 sigmoid
"""
# Out:
# '\nPARAMETROS:\nSVR 10 0.5 sigmoid\n'
